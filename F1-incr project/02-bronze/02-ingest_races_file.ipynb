# %% [markdown]
# #Races Data ingestion

# %%
# %run ../00-common/01-env-variables

# %%
# %run ../00-common/02-bronze-helpers

# %%
dbutils.widgets.text('batch_id' , "")
v_batch_id = dbutils.widgets.get('batch_id')

# %%
source = f"{landing_file_path}/{v_batch_id}/races.csv"
table_name = f"{catalog_name}.{bronze_schema}.races"

# %%
from pyspark.sql.types import StringType, IntegerType, StructField, StructType , DateType

races_schema = StructType([
    StructField('season' , IntegerType()),
    StructField('round' , IntegerType()),
    StructField('url' , StringType()),
    StructField('raceName' , StringType()),
    StructField('date' , DateType()),
    StructField('circuitId' , StringType())
])

# %%
races_df = (
    spark.read.format('csv')
    .option('header', True)
    #.option('inferSchema', True)
    .schema(races_schema)
    .load(source)
)

# %%
display(races_df)

# %% [markdown]
# ## Adding metadata

# %%
from pyspark.sql import functions as F
races_df = add_ingestion_metadata(races_df)

# %%
display(races_df)

# %%
write_to_bronze(races_df,table_name,v_batch_id)

# %%
# %sql
select * from formula1.bronze.races
