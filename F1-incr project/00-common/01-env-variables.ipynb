# %%
#unity catalog object names
catalog_name = 'formula1incr'
bronze_schema = 'bronze'
silver_schema = 'silver'
gold_schema = 'gold'

# %%
# paths

landing_file_path = '/Volumes/formula1incr/landing/files'
