# %%
# %run ../00-common/01-env-variables

# %%
bronze_table = f"{catalog_name}.{bronze_schema}.races"
silver_table = f"{catalog_name}.{silver_schema}.races"

# %%
races_df = spark.table(bronze_table)
display(races_df)

# %%
reaces_url_removed_df = races_df.select('season',
'round' ,'raceName',
'date',
'circuitId',
'ingestion_timestamp',
'source_file')

# %%
reaces_df_reneamed = reaces_url_removed_df.withColumnsRenamed(
    {'raceName' : 'race_name',
     'circuitId' : 'circuit_id'
     })

# %%
distinct_races = reaces_df_reneamed.dropDuplicates(['season', 'round'])

# %%
display(distinct_races)

# %%
distinct_races.write.mode('overwrite').saveAsTable(silver_table)
